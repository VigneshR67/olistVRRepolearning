# %%
from pyspark.sql import SparkSession
from raw_ingestion.logging.decorators import log_execution

def read_csv(
    spark: SparkSession,
    csv_path: str,
    options: dict
):
    return (
        spark.read
        .options(**options)
        .csv(csv_path)
    )
