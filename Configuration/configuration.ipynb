# %%
#configuration to read files from adls bucket with azure key vault
#configuration to sql vignesh adding database

# %% [markdown]
# 1> Configuration to read the files with account key
#
# 2> Utility file to verify the connection and tokens
#
# 3> Just one dummy configuration to read from postgress and oracle db
