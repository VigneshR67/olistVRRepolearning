# %%
# Databricks notebook source

# %%
#dbutils.widgets.text("process_date", "")
process_date = dbutils.widgets.get("process_date")

if not process_date:
    raise ValueError("process_date is mandatory")

# %%
from raw_ingestion.orchestrator import run_pipeline
from raw_ingestion.configs import load_source_config
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.getOrCreate()

# %%
config = load_source_config(
    source_name="olist_customers",
    process_date=process_date
)

# %%
run_pipeline(
    spark=spark,
    config=config
)
